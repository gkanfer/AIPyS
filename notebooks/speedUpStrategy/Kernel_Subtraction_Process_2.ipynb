# %% [markdown]
# The new AIPS layout will have global segmentation initially, followed by basic Bayesian categorization, switching later to cellpose segmentation and concluding with pytorch CNN phenotypic cell identification.\
# 2.1.  Our target image will go through the classification process.\
# 2.2. End kernel size will be determined\
# 2.3. Images will be partitioned by running window and binary labeled.

# %%
from AIPyS.Granularity_cellprofiler import  GranulaityMesure
import glob

# %%
# data_dir = '/data/kanferg/Images/Pex_project/Subrah_2024/022419_catGFP/class1/'
# files = glob.glob(data_dir + '*tif')

# %%
from AIPyS.Granularity_cellprofiler import  GranulaityMesure
import glob
data_dir = '/data/kanferg/Images/Pex_project/Subrah_2024/022419_catGFP/class1/'
outputTableName = '/data/kanferg/Images/Pex_project/Subrah_2024/022419_catGFP/temp'
outPath = "test"
files = glob.glob(data_dir + '*tif')
#start_kernel = 2,end_karnel = 50,kernel_size = 20,outputTableName = None,outPath = None
GranulaityMesure(Image_name = files[0],block_size_cyto = 3, offset_cyto = -5, global_ther = 0.51, clean  = 3,outputTableName = outputTableName,outPath = outPath)

# %%
# def saveCSV(imagename):
#     GranulaityMesure(Image_name = files[0],block_size_cyto = 3, offset_cyto = -5, global_ther = 0.51, clean  = 3, outputTableName = outputTableName,outPath = outPath)
# for file in files:
#     saveCSV(imagename = os.basename(file))
